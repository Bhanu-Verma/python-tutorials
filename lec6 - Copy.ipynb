# %%
if True:
  print("it is the true condition\n")
# Out:
# it is the true condition

# %%
if False:
  print("it is the false condition\n")

# %%
if 3<5:
  print("3 is less than 5\n")
else:
  print("3 is not less than 5\n")
# Out:
# 3 is less than 5

# %%
msg="hello"
if msg == 'hello':
  print("it is saying hello\n")
elif msg=="khuda hafij":
  print("khuda hafij\n")
else:
  print("it is saying namastey\n")
# Out:
# it is saying hello

# %%
#boolean expressions in python are and, or, not
a=5
b=8
if a==5 and b==8:
  print("it is good")
else:
  print("not good")
# Out:
# it is good

# %%
condition=""      #empty string or any emptything is the false
if condition:
  print("it is true\n")
else:
  print("it is false\n")
# Out:
# it is false
