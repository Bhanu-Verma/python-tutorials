# %%
student={'name':'Bhanu', 'roll no-':21, 'cpi':9.63}
print(student)
print(student['name'])
# Out:
# {'name': 'Bhanu', 'roll no-': 21, 'cpi': 9.63}
# Bhanu

# %%
print(student.get('name'))
# Out:
# Bhanu

# %%
#to add a new pair in our dictionary we needn't do anything we just write its assignment operator
student['phone']='7037589173'
print(student)
# Out:
# {'name': 'Bhanu', 'roll no-': 21, 'cpi': 9.63, 'phone': '7037589173'}

# %%
student.update({'pass':True})   #it takes a dictionary as argument and update it in the original dictionary
print(student)
# Out:
# {'name': 'Bhanu', 'roll no-': 21, 'cpi': 9.63, 'phone': '7037589173', 'pass': True}

# %%
del student['cpi']
print(student)
# Out:
# {'name': 'Bhanu', 'roll no-': 21, 'phone': '7037589173', 'pass': True}

# %%
print(len(student))   #to get the length
print(student.values())
print(student.items())
# Out:
# 4
# dict_values(['Bhanu', 21, '7037589173', True])
# dict_items([('name', 'Bhanu'), ('roll no-', 21), ('phone', '7037589173'), ('pass', True)])

# %%
#traversal of the dictionary
for key, value in student.items():
  print(key,value)
# Out:
# name Bhanu
# roll no- 21
# phone 7037589173
# pass True
