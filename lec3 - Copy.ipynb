# %%
num=3
print(type(num))        #
# Out:
# <class 'int'>

# %%
n=3.45
print(type(n))
# Out:
# <class 'float'>

# %%
print(3+4)
# Out:
# 7

# %%
print(4/3)    #it gives the output as a float
# Out:
# 1.3333333333333333

# %%
print(4//1)     #it gives the output as an integer
# Out:
# 4

# %%
print(8**3)
# Out:
# 512

# %%
print(17%7)
# Out:
# 3

# %%
print(abs(-3))
# Out:
# 3

# %%
print(round(3.8577,3))
# Out:
# 3.858

# %%
i=98
j=12
print(j<=i)
# Out:
# True

# %%
print(j>i)
# Out:
# False

# %%
num1='12'
num2='35'
num1=int(num1)
num2=int(num2)
print(num1+num2)
# Out:
# 47
