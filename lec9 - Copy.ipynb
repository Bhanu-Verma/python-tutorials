# %%
import random as rd
arr=[1,2,3,4,5]

print("Give a nuber b/w 1 and 5\n")
n=int(input())
x=rd.choice(arr)
print(x)    
if n==x:
  print("You win the game\n")
else: 
  print("You lost the game\n")
# Out:
# Give a nuber b/w 1 and 5
#
# 4
# 1
# You lost the game

# %%
import datetime
import calendar

today = datetime.date.today()
print(today)
# Out:
# 2023-03-18

# %%
print(calendar.isleap(2016))
# Out:
# True

# %%
import os

os.getcwd()
# Out:
# '/content'
