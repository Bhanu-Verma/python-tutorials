# %%
message='hello world!'      #message is a string 
print(message)              #this is to print the string
# Out:
# hello world!

# %%
print(len(message))     #len function is used to get the length of the string
# Out:
# 12

# %%
print(message[0])       #this is used to get the value at the index 0
# Out:
# h

# %%
#print(message[0:5])       #this is used to get the string starting with 0(included) and 5(excluded)
#print("\n")
print(message[0: ])       #it will print all the letters after the index 0
# Out:
# hello world!

# %%
print(message.lower())
# Out:
# hello world!

# %%
print(message.upper())
# Out:
# HELLO WORLD!

# %%
print(message.capitalize())
# Out:
# Hello world!

# %%
print(message.count('l'))     #it gives the count of letter 'l' in the given string
# Out:
# 3

# %%
print(message.find('hello'))    #it gives the index of the our passed string or the letter if it doesn't exist then returns -1
# Out:
# 0

# %%
message=message.replace("world!","universe")      #it replaces first argument to second but not inplace
print(message)
# Out:
# hello universe

# %%
greeting="hello"
name="bhanu"        #it is not a good way 
print(greeting + " " + name)
# Out:
# hello bhanu

# %%
#formatted string method 
message="{} {} welcome".format(greeting,name)
print(message)
# Out:
# hello bhanu welcome
